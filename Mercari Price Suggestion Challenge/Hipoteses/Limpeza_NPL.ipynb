# %% [markdown]
# <a href="https://colab.research.google.com/github/anachavesv8/Bootcamp_Blue/blob/main/Limpeza_NPL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import random
import math

import matplotlib.pyplot as plt
import seaborn as sns


import numpy as np
import pandas as pd
import re

import sklearn

from nltk import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer

from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.model_selection import train_test_split

from sklearn.metrics.pairwise import cosine_similarity

from scipy.sparse import csr_matrix
from sklearn.neighbors import NearestNeighbors

# %%
train = pd.read_csv('/content/drive/MyDrive/Datasets/train.tsv', sep = '\t')
test = pd.read_csv('/content/drive/MyDrive/Datasets/test.tsv', sep = '\t')

def data(n, seed):

    datas = []
    
    random.seed(seed)
    for i in range(n):
        dia_maximo = 30
        dia_minimo = 1
        mes_maximo = 12
        mes_minimo = 1
        
        dia = int(round(random.random() * (dia_maximo - dia_minimo) + dia_minimo, 0))
        mes = int(round(random.random() * (mes_maximo - mes_minimo) + mes_minimo, 0))
        
        datas.append(str(dia)+'-'+str(mes)+'-2018')
        
    return datas

def estoque(n, seed):

    np.random.seed(seed)
    mu, sigma = 1, 20
    s = np.random.normal(mu, sigma, n)
    s[s < 0] = s[s < 0] * -0.5
    s = s.astype(int)
    s[s < 1] = 1
    
    return s

train['date']  = data(n = train.shape[0], seed = 10)
train['stock'] = estoque(n = train.shape[0], seed = 10)

test['date']  = data(n = test.shape[0], seed = 15)
test['stock'] = estoque(n = test.shape[0], seed = 15)

train.drop('train_id', axis=1, inplace=True)
train['item_condition_id'] = train['item_condition_id'].astype('str')

# %% [markdown]
# ### Objetivo: Entender o comportamento dos dados através de visualizações
#
# Podemos dizer que a variável 'price' é a variável target, ou seja, a variável que devemos prever. Dessa forma, a maior parte desta análise exploratória envolverá esta variável.

# %%
from numpy.lib.function_base import delete
rotulos = [i for i in train['category_name'].fillna('missing/missing/missing').str.split("/")]
rotulos

gen_cat = []
sub1_cat = []
sub2_cat = []

for i in range(0,len(rotulos)):
  gen_cat.append(rotulos[i][0])
  sub1_cat.append(rotulos[i][1])
  sub2_cat.append(rotulos[i][2])

train['gen_cat'] = gen_cat
train['sub1_cat'] = sub1_cat
train['sub2_cat'] = sub2_cat

del gen_cat
del sub1_cat
del sub2_cat

# %%
train
# Out:
#                                           name item_condition_id  \
# 0          MLB Cincinnati Reds T Shirt Size XL                 3
# 1             Razer BlackWidow Chroma Keyboard                 3
# 2                               AVA-VIV Blouse                 1
# 3                        Leather Horse Statues                 1
# 4                         24K GOLD plated rose                 1
# ...                                        ...               ...
# 1482530             Free People Inspired Dress                 2
# 1482531          Little mermaid handmade dress                 2
# 1482532  21 day fix containers and eating plan                 2
# 1482533                 World markets lanterns                 3
# 1482534          Brand new lux de ville wallet                 1
#
#                                              category_name   brand_name  \
# 0                                        Men/Tops/T-shirts          NaN
# 1        Electronics/Computers & Tablets/Components & P...        Razer
# 2                              Women/Tops & Blouses/Blouse       Target
# 3                       Home/Home Décor/Home Décor Accents          NaN
# 4                                  Women/Jewelry/Necklaces          NaN
# ...                                                    ...          ...
# 1482530                             Women/Dresses/Mid-Calf  Free People
# 1482531                           Kids/Girls 2T-5T/Dresses       Disney
# 1482532     Sports & Outdoors/Exercise/Fitness accessories          NaN
# 1482533                 Home/Home Décor/Home Décor Accents          NaN
# 1482534                  Women/Women's Accessories/Wallets          NaN
#
#          price  shipping                                   item_description  \
# 0         10.0         1                                 No description yet
# 1         52.0         0  This keyboard is in great condition and works ...
# 2         10.0         1  Adorable top with a hint of lace and a key hol...
# 3         35.0         1  New with tags. Leather horses. Retail for [rm]...
# 4         44.0         0          Complete with certificate of authenticity
# ...        ...       ...                                                ...
# 1482530   20.0         1  Lace, says size small but fits medium perfectl...
# 1482531   14.0         0   Little mermaid handmade dress never worn size 2t
# 1482532   12.0         0          Used once or twice, still in great shape.
# 1482533   45.0         1  There is 2 of each one that you see! So 2 red ...
# 1482534   22.0         0  New with tag, red with sparkle. Firm price, no...
#
#                date  stock            gen_cat             sub1_cat  \
# 0         18-6-2018     27                Men                 Tops
# 1         18-3-2018     15        Electronics  Computers & Tablets
# 2        25-10-2018     14              Women       Tops & Blouses
# 3         20-3-2018      1               Home           Home Décor
# 4         16-5-2018     13              Women              Jewelry
# ...             ...    ...                ...                  ...
# 1482530  13-10-2018      2              Women              Dresses
# 1482531   6-10-2018     10               Kids          Girls 2T-5T
# 1482532    6-8-2018     15  Sports & Outdoors             Exercise
# 1482533   13-2-2018     20               Home           Home Décor
# 1482534  28-10-2018      9              Women  Women's Accessories
#
#                     sub2_cat
# 0                   T-shirts
# 1         Components & Parts
# 2                     Blouse
# 3         Home Décor Accents
# 4                  Necklaces
# ...                      ...
# 1482530             Mid-Calf
# 1482531              Dresses
# 1482532  Fitness accessories
# 1482533   Home Décor Accents
# 1482534              Wallets
#
# [1482535 rows x 12 columns]

# %%
#Instalando a biblioteca
# !pip install spacy

import spacy
import spacy.cli

spacy.cli.download("en_core_web_sm")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: spacy in /usr/local/lib/python3.7/dist-packages (3.4.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.21.6)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (21.3)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.0.3)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.6.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (4.64.1)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (8.1.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy) (3.0.7)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.0.8)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.11.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in /usr/local/lib/python3.7/dist-packages (from spacy) (3.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.0.6)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (3.3.0)
# Requirement already satisfied: typing-extensions<4.2.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy) (4.1.1)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.4.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.10.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy) (57.4.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.23.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.10.0,>=1.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.9.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.4.4)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.6->spacy) (3.8.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy) (3.0.9)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy) (5.2.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.6.15)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.7/dist-packages (from thinc<8.2.0,>=8.1.0->spacy) (0.7.8)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.7/dist-packages (from typer<0.5.0,>=0.3.0->spacy) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy) (2.0.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1482535 entries, 0 to 1482534
# Data columns (total 12 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   name               1482535 non-null  object
#  1   item_condition_id  1482535 non-null  object
#  2   category_name      1476208 non-null  object
#  3   brand_name         849853 non-null   object
#  4   price              1482535 non-null  float64
#  5   shipping           1482535 non-null  int64
#  6   item_description   1482531 non-null  object
#  7   date               1482535 non-null  object
#  8   stock              1482535 non-null  int64
#  9   gen_cat            1482535 non-null  object
#  10  sub1_cat           1482535 non-null  object
#  11  sub2_cat           1482535 non-null  object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 135.7+ MB

# %%
train1 = train.copy() 
train1.isna().sum().loc[train1.isna().sum()>0].sort_values()
# Out:
# item_description         4
# category_name         6327
# brand_name          632682
# dtype: int64

# %%
train1.dropna(subset=['item_description', 'category_name'], inplace=True)

# %%
train1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1476204 entries, 0 to 1482534
# Data columns (total 12 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   name               1476204 non-null  object
#  1   item_condition_id  1476204 non-null  object
#  2   category_name      1476204 non-null  object
#  3   brand_name         846982 non-null   object
#  4   price              1476204 non-null  float64
#  5   shipping           1476204 non-null  int64
#  6   item_description   1476204 non-null  object
#  7   date               1476204 non-null  object
#  8   stock              1476204 non-null  int64
#  9   gen_cat            1476204 non-null  object
#  10  sub1_cat           1476204 non-null  object
#  11  sub2_cat           1476204 non-null  object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 146.4+ MB

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
stop_words = stopwords.words('english')
lemmatizer = WordNetLemmatizer()
stemmer = PorterStemmer()
vectorizer = CountVectorizer(analyzer='word', ngram_range=(1, 1))
tfidf_transformer = TfidfTransformer()

# %%
titulos = train1.name
descricao  = train1.item_description.tolist()

# %%
# funcao para tratar cada palavra e remover stopwords
def processamento(tokens):
    
    token_processado = []
    for token in tokens:
        token = token.lower()
        token = lemmatizer.lemmatize(token)
        
        if token not in stop_words:
            token = stemmer.stem(token)
            token_processado.append(token)
        
    return token_processado

documentos = []
for titulos in titulos:
    
    # expressao regular para remover pontuacoes do texto
    descricao = re.sub(r'[^\w\s]','', titulos)
    tokens = processamento(word_tokenize(titulos))
    
    documentos.append(' '.join(tokens))

# %%
X_train_counts = vectorizer.fit_transform(documentos)
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)

X = X_train_tfidf

# %%
documentos
# Out:
# ['mlb cincinnati red shirt size xl',
#  'razer blackwidow chroma keyboard',
#  'ava-viv blous',
#  'leather hors statu',
#  '24k gold plate rose',
#  'bundl item request ruie',
#  'acacia pacif tide santorini top',
#  'girl cheer tumbl bundl 7',
#  'girl nike pro short',
#  'porcelain clown doll checker pant vtg',
#  'smashbox primer',
#  'new v pi k bodi mist',
#  'black skater dress',
#  'sharpen eras',
#  'hold dogs2016 minnetonka boot',
#  'sephora tart birthday gift',
#  'glitter eyeshadow',
#  "new : babi k'tan activ babi carrier",
#  "face limit `` merri macaroon ''",
#  'cream/ beig front cross shirt',
#  'torrid nautic peplum tube top',
#  'nwt v ultim sport bra 34ddd',
#  'galaxi s7 edg ( unlock ) 32gb',
#  'tripl car charger',
#  'black red basebal tee',
#  'air jordan carmin 6',
#  'otterbox defend iphon 6 plus/6 plu',
#  'lularo black white polka dot',
#  'forever21 floral romper strapless',
#  'kendra bundl',
#  'face better sex mascara qty3',
#  'new lularo leg , star',
#  'pink bra 36d',
#  'caudalí beauti elixir spray',
#  'four puppi dog stuf anim ty',
#  'black capri leg w/ flower one size',
#  'black bag 30',
#  'armour maroon gray shirt metal',
#  'xbox one',
#  'victoria secret 34 c corest top',
#  'kyli birthday edit',
#  'tropic flower print bra pink',
#  'lot korean natur republ face mask',
#  'apricot beig stick foundat ! !',
#  'glass christma bowl✨',
#  "woman 's north face puffer vest",
#  'metal purpl slime sparkl',
#  'brandi melvil shoulder crop top',
#  'lululemon wunder crop',
#  'youniqu 3d fiber lash mascara',
#  'michael kor crossbodi',
#  'led kid shoe size 3 size 9',
#  'hot wheels-sup tuner car set',
#  "pink victoria 's secret lace bandeau",
#  "rae dunn `` hug '' mug",
#  'vintag wood jewelri lot',
#  'new josi maran divin drip',
#  'infantino babi carrier',
#  'new yokai watch backpack',
#  'hv-900 sport bluetooth headset',
#  '1/4 ct diamond engag ring !',
#  'nwt lularo french bulldog leg',
#  'high waist levi jean',
#  'highwaist distress denim short',
#  'patagonia fleec jacket',
#  'new holiday barbi',
#  'silver choker itali 925',
#  "h & woman 's long hors sweater",
#  '( ) armour half zip jacket !',
#  'iphon 6/6 marbl design case',
#  'adida ultraboost shoe',
#  'partner crime necklac shipfromchina',
#  'list aknuckles1',
#  'toddler vineyard vine hat',
#  'rae dunn beauti beast',
#  'littlest pet shop accessori bon',
#  'black & burgundi bikini bottom',
#  'aura fluorit doubl termin wand',
#  'trump shirt',
#  'sea wee size 0',
#  'matern top bundl',
#  '* hold * free today-it cosmet cc hold',
#  'mascara bundl',
#  'eyebrow essenti kit medium ; brown',
#  "woman 's espresso pink coral shirt xl",
#  'v pink sheet set',
#  'jillian michael bodyshr fit dvd',
#  'melissa doug fold go kitchen',
#  'misti tentacruel foil pokemon card',
#  'nike boy sneaker',
#  'jewel holder',
#  'goosebump horrorland game',
#  'silver jean size 11',
#  'crimson tide alabama t-shirt',
#  'hatchim draggl',
#  'gap canva shoe { size 8 }',
#  'lumi air airbrush makeup system',
#  'iphon 5 mickey ear case',
#  'gucci',
#  'size 6 watercolor inspir crop',
#  'muscl t-shirt',
#  'rock reviv 24 bootcut',
#  'black boho floral embroid maxi dress',
#  'kid adida',
#  'pictur frame',
#  'leather fossil wallet',
#  'floral two piec tracksuit set',
#  'boot nwt 6.5',
#  'new duck boot sz.7.5',
#  'rose gold necklac silver stud',
#  'lularo leg nwt !',
#  'nwt victoria secret bathingsuit bottom',
#  'huda beauti lash',
#  'marc jacob honey',
#  'hold kesha - sperri shoe ua pant',
#  'steve madden wedg',
#  'lebron soldier 9 size 7',
#  'eyeko liquid eyelin',
#  'pink bodi mist',
#  "victoria 's secret pink zip hoodi",
#  'halloween sweater shirt',
#  'ten 3000 lower price',
#  'xl dress built bra .',
#  'miss skinni jean 26',
#  'ferragamo belt',
#  'urban outfitt black skort',
#  'spartina leather key fob',
#  'zodiac tapestri',
#  'primit pillow',
#  'doubl layer studio microphon mic',
#  'lularo disney leg tigger',
#  'motu skeletor dorbz',
#  '. bbw mentha lip balm',
#  'new brown leather fossil purs .',
#  'nar dual intens cheek palett',
#  'brandi melvil lavend skirt',
#  'adida superstar sneaker',
#  "2breal girl 's boutiqu dress w adjstrap",
#  'head shoulder 2 1',
#  'zelda link amiibo .',
#  'manolo blanik sz 35 1/2',
#  'sweater',
#  'lauren conrad pink polka dot blous',
#  'nwt bumi , west paw design dog toy',
#  'air jordan 1 bred 2016',
#  'teal lululemon sucba zip',
#  'mk purs',
#  'pyrex speckl line chip & dip',
#  'like new iphon 5c',
#  'kate spade myli black hobo crossbodi',
#  "nike men 's dri-fit sleeveless shirt tee",
#  'nwt 32d victoria secret bling bra',
#  'new lularo tc purpl black siames cat',
#  'iredes fishbowl slime ~ free ship [ rm ]',
#  'mk bundl lolita',
#  'opi polish hold chi thuy',
#  'batman : death famili one volum',
#  'angel soft toilet paper bundl',
#  "new xlg woman 's sexi summer halter top",
#  '7 leapster game',
#  'matern swim top',
#  'fantast four set',
#  'gorgeou crystal drop ear',
#  'bare miner nude matt liquid lipcolor',
#  'prada candi eau de parfum',
#  'pure karen low perfum',
#  'pandora timeless eleg ring',
#  'bundl broadway',
#  '1993 preciou moment bear cooki jar',
#  'tranquilo mat',
#  'toddler nike tenni shoe',
#  'rue 21 long cardigan',
#  'realher eveshadow pallet',
#  'paw paw usb cabl saver costum',
#  'amw precis bench scale',
#  'nba 2k14 brand new seal',
#  'v pink 1/2zip collar sz',
#  'iphon 7 flexibl phone case',
#  'go ! capri tight',
#  'free ship nwt v pink l boyshort',
#  "victoria 's secret pink night shirt",
#  '12 month reebok track suit',
#  'tank top',
#  "auth . pandora bracelet s-8 ''",
#  'new g guess shoe',
#  '3d moodstruck fiber lash mascara',
#  "kid jordan retro 8 's size 10c",
#  'marucci pro cut',
#  "victoria 's secret small bikini top",
#  'rae dunn mr 2017',
#  'cheroke purpl xxsp scrub pant',
#  'lularo leg sugar skull',
#  'shaymin ex',
#  'black tom',
#  '✨free ship✨ colourpop trap',
#  'lularo l classic',
#  'nike air max 95 essenti',
#  'pregnanc sash',
#  'bath & bodi work banana kiwi colada',
#  'frozen hat glove set winter girl new',
#  'rae dunn tea teapot',
#  'racerback tank top',
#  'brand-new underwear',
#  'hamilton beach electr kettl 10c',
#  'armour blue hoodi size small',
#  'eo lip balm strawberri sorbet bundl 10',
#  'samsung hdmi cord',
#  'north face oso jacket',
#  'newborn girl holiday dress',
#  'disneyland charact key chain',
#  'mesh/velvet bodysuit',
#  'face melt liquid lipstick',
#  'xx lularo carli',
#  'kate spade glitter bug wristlet new',
#  'ysl otl bdj chevrett 2a clutch new',
#  'firm tiffani & co . graduat necklac',
#  'scentsi tester ( 36 )',
#  'glamglow youthcleans .',
#  'toddler dress shoe',
#  'faux leather sandal',
#  'mori lee prom dress',
#  'hold sherri hill prom black dress',
#  'pink ultim fit half zip',
#  'glitter matt eyeshadow palett',
#  "victoria 's secret pj set size med",
#  "men 's volcom short",
#  'amazon fire stick',
#  'berkley bad shad 5',
#  'banana republ leather boot size 9',
#  'abh brow powder duo',
#  'never use hand bag plu match wallet',
#  'rockstar bundl ( xbox 360 / one )',
#  'hello kitti orizuru geisha kimono plush',
#  'armor leg',
#  'apt . 9 hand/should bag',
#  'lego harri potter year 1-4 wii',
#  'girl size 10 justic jean bundl',
#  'zagg invis shield ipad air',
#  '1998 sp authent derek jeter',
#  'mk vanilla wallet wristlet phone case',
#  'lularo leg , bird wire',
#  'american eagl high waist short',
#  'cole haan wristlet',
#  'dove bodi wash',
#  'love danc draw string bag',
#  'jessica simpson shoulder top small',
#  'pandora dazzl daisi cz dangl charm',
#  'scentsi bath tab',
#  'lularo chevron tie dye sarah',
#  'abh dipbrow pomad',
#  'giorgio armani regeness',
#  'calvin klein fragranc set',
#  'kendra scott black iridesc ell',
#  "'ll cri want sticker",
#  "brand new men 's sock",
#  'f lip smacker shine',
#  'simpli southern pink preppi long sleev',
#  'babi bomber jacket/ puffer jacket bundl',
#  'advocar shake',
#  'gray armour pant',
#  'scarlet spider funko pop',
#  'ricki garner',
#  'new ulta makeup lot',
#  'jordan 4 retro 6c',
#  'larg coach bag',
#  'new york basebal hat',
#  'ugg australia shoe paper bag ( free ship )',
#  'jo malon wild blueberri',
#  'jbl flip 2 portabl bluetooth speaker',
#  'adida woman pink size larg zip',
#  'boy puma t-shirt',
#  'black swim suit bottom',
#  'criss cross black tank crop top',
#  'nintendo 64',
#  'request bundl swag773',
#  'fashion nova longsleev',
#  'sweet sixteen pictur frame new',
#  'rocket balloon',
#  'red stripe fidget hand spinner',
#  'aztec black white medium dress',
#  'doctor tardi',
#  '5 ring bundl',
#  'waist trainer/xsmall/ship today',
#  'forev 21 pink top',
#  'set 7 dragon ball',
#  'lularo hipster penguin',
#  "free peopl `` free fallin '' v-neck",
#  'bundl',
#  'free ship lularo stork leg',
#  'kat von outlaw',
#  'grate thank bless wood art box',
#  'nwot lululemon present pouch',
#  'overs gold circl clear len glass',
#  'black booti',
#  'photographi fish prop',
#  "jordan 's kid size 6",
#  'free ship glamglow glow moistur',
#  'jordan iphon case plu',
#  'free ship 38g freya bra',
#  'tori burch shoulder purs',
#  'croc',
#  '5.8oz best seller slime sampler',
#  'mini safe w/ money slot',
#  'justin bieber sing toothbrush',
#  'travel size prada fragranc',
#  'free ship beig silk tank top',
#  'genuin kid 2t dress',
#  'boot',
#  'new time turner wolf necklac bundl',
#  "men 's nike forc shoe",
#  'jordan flight sz 12 ( free ship )',
#  'new trendi 80 style digit gold watch !',
#  'reduc lularo woodland creatur',
#  'pearl ear chanel',
#  'v pink hoodi nwt/ free ship',
#  'makeup bundl',
#  "❤☺nyx sued `` sandstorm '' liquid lippy☺❤",
#  'profession precis digit scale',
#  'vera bradley eyeglass case',
#  '! ship free ! iphon 5pc cables-pk',
#  'coloresci spf powder + brush',
#  'pink & black yoga pant',
#  'tv wall mount',
#  'lularo tc leg . htf ! ! !',
#  'nike dri fit leg size small',
#  'old navi jean jacket',
#  'pink ultim yoga leg',
#  '( ) 7 vs/v pink item',
#  'comfort color !',
#  '0g tunnel',
#  'toddler loafer',
#  'halloween tree',
#  'eyelash growth serum',
#  'rae dunn icon savor oval ( 3 )',
#  'new coach ray outlin sig high top',
#  'milk pencil case',
#  'nike pro',
#  'miss sz 28',
#  'nivea lip balm',
#  'stainless steel window canist set',
#  'maxi rib tank dress size sm',
#  'gymshark crop bundl -l',
#  'tori burch gladiat sandal 6.5',
#  'rae dunn tea canist',
#  'h & polka dot nude dress',
#  'lipsens bombshel',
#  'adida runner',
#  'stussi vintag dot ragland larg',
#  'lularo halloween frankenstein leg',
#  '2-men xxl cruis ship t-shirt nwot',
#  'ralph lauren blake shirt l',
#  'buckl jacket',
#  'solar power owl bobbl',
#  'vera wang lovestruck perfum',
#  'murad skincar lot',
#  'tom size t9',
#  'express peplum top',
#  'vintag action figur',
#  'zara babi boy sweater size 18/24',
#  'ben nye',
#  'nike rosh shoe boy',
#  'bath & bodi work cool citru basil',
#  'marc jacob pretti nylon backpack black',
#  "woman 's nike dri fit short",
#  'new adida basebal cleats/spikes/sho',
#  'north face polartec fleec jacket',
#  'size small southern boutiqu tank',
#  '3 new pair pink sock free ty gift',
#  'hold angel',
#  'brandi melvil indian skull crop tank',
#  'blue flame black bikini top medium',
#  "nwt men 's 32x30 jean",
#  'v pink logo band boyshort',
#  '2 liz lang matern dress new medium',
#  "lululemon skinni woman 's pant size 6",
#  'reserv aria donotbuy ! aria',
#  'camouflag pant',
#  'new royal blue hh scrub set larg tall',
#  '1 new iphon ipad charger',
#  '2 pair born soft sandal size 9',
#  'tye dye ivori ella long sleev',
#  'nip extra larg v pink sherpa blanket',
#  'mvmt movement watch tan white',
#  "victoria 's secret swim suit",
#  'cozi boot',
#  'green shoulder long sleev blous',
#  'nwot lularo chevron disney rose',
#  'nail nail polish set',
#  "victoria 's secret red/cor garter skirt",
#  'white versac sun shade',
#  'bb cream',
#  "new ny giant woman 's bling jersey top",
#  'nwt v pink tote',
#  'bean kid sz 1 winter snow boot guc',
#  'victoria secret perfum',
#  'nwt lularo 3xl randi',
#  'armour tank',
#  'silk blous 2',
#  'tankini',
#  'guess blue bandag dress',
#  'brand new mug rae dunn collect !',
#  'f21 satin bralett sz medium',
#  'moana dvd',
#  'hello kitti loungefli',
#  'authent blue black nike foam 7c',
#  'charlott russ lace dress',
#  'smart watch android io',
#  'michael kor sandal',
#  'littl poni friendship magic set',
#  'hp 952 xl hp 952 color',
#  'necklac',
#  '10ft red nylon braid cabl appl',
#  'kyli jenner birthday edit lippi',
#  "2 pair men 's superman sock . free ship",
#  'eyebrow bikini line trimmer / razor',
#  'nike leg',
#  'youniqu splash liquid lipcolor',
#  'sz 11 jean',
#  "victoria 's secret pink boyfriend med",
#  'japonesqu solid brush cleaner',
#  'kodak easi share camera !',
#  'fitbit',
#  'hello kitti water bottl & 2 touch lamp',
#  'black velvet skater dress',
#  'dress',
#  'rae dunn bon appetit bowl',
#  'overs grey & gold la vega shirt l',
#  'white capri',
#  "victoria 's secret loung sweatpant",
#  "'garbag '' tee",
#  'anastasia ultim glow',
#  'green kappa delta shirt',
#  'flash sale kkw creme lipstick',
#  'cross chain',
#  '3 pair a.e . 32/32',
#  'kyri 2',
#  'jaclyn hill palett',
#  'new seattl seahawk beani',
#  'chocol abh dipbrow',
#  'bundl lexi',
#  'colourpop lippi stix konichiwa',
#  '35 thank sticker free ship',
#  'milani eyeshadow pallett',
#  'rae dunn tea pot lid jleman',
#  'black & white market blous',
#  'lularo tall curvi leg',
#  "woman 's nike sweatshirt hoodi",
#  'coral forev 21 long dress size small',
#  'brandi bundl ! !',
#  'tide pod',
#  'decor hang',
#  'adida high top basketbal shoe',
#  'magic throwback nick anderson',
#  '21 day fix',
#  'boutiqu top',
#  'tool lateralu cd',
#  '4t lot shirt',
#  'black distress jean',
#  'victoria secret pink sweatpant',
#  "woman 's size nike drifit short",
#  'go pro chest har',
#  'slide smart watch',
#  'medium lularo randi nwt',
#  'chines decor vase pic . beauti',
#  'mk watch',
#  'babi k-swiss shoe 1daysal',
#  'kyli jenner',
#  "victoria 's secret tote bag",
#  'nike track shoe',
#  'lularo nwt amelia 3xl',
#  'hold engravemybon',
#  'nightmar christma hoodi',
#  'h & woman x hoodi',
#  'v pink full zip hoodi x',
#  'vintag cyber pup jr. dog walk',
#  'tori burch black leather flat 9.5',
#  "woman 's convers star tenni shoe 7",
#  'bamboo adult toothbrush 2-pack',
#  'blue ombré sequin homecom dress',
#  'peanut butter air forc one',
#  'ucla sweatshirt - youth',
#  'maybellin mascara # 130 blackest black',
#  'jordan toddler 5c',
#  'patagonia tan vest',
#  'lularo tc pink camera leg',
#  'la girl banana yellow set powder',
#  "adida men 's gray athlet top medium",
#  'lena cosmet jason liquid lipstick',
#  'marvel legend captain america',
#  '5 disney princess dress',
#  'call duti black op 3 ps4',
#  'carolin pollack necklac',
#  'columbia jacket',
#  "woman 's latch belt",
#  "nintendo 64 men 's shirt size 2xl",
#  'anastasia lipgloss - sepia',
#  'lush',
#  "bundl ell 's boutiqu",
#  'new tart mini sampl set',
#  'new box belkin iphone/ipad charger !',
#  'strappi tangerine/orang monokini',
#  'pink summer tank',
#  'banana republ polo',
#  'brandi melvil holo sticker bundl',
#  '3d mink fals eyelash w glue',
#  'like new nike short !',
#  "✨girl 's fur vest ✨size medium",
#  'nike air max tava',
#  'anastasia beverli hill glow',
#  'pink ( victoria secret ) small w/ phone ca',
#  'forev red fragranc mist',
#  'raider zip hoodi',
#  'burgandi snow flake leg',
#  'first remi indian remi virgin hair',
#  'super awesom bundl',
#  'tide pod bundl',
#  '☆vs☆ 36dd dream angel pushup',
#  'lularo julia/jordan athlet pant',
#  'boot',
#  'pixar * car * blanket * free ship *',
#  'new lularo randi shirt sz',
#  'navi blue sweater',
#  'elf bell beauti book',
#  'ballerina doll',
#  'cam matthew hold felder',
#  "yu darvish '16 platinum ice card ranger",
#  "new unisex convers woman 's 11/men 's 9",
#  'michael kor',
#  'bali warmer',
#  'doubl wreath holder',
#  'pilaten blackhead remover,60 ml',
#  '2 victoria secret logo boy short panti l',
#  'jordan boy outfit size 3',
#  'pick 5 new disney dvd 24',
#  'rae dunn sunshin mug',
#  'tender night paperback . brand new',
#  'beauti bundl color pop , bare miner',
#  'v pink vneck campu tee',
#  'sweeti bell poni toy',
#  'nwt lularo tween thunder storm leg',
#  'burberri small canterburi horsesho tote',
#  'real techniqu brush lot',
#  'new true religion outfit size 6 month',
#  'ring',
#  'genuin fur coat',
#  "nwt north face woman 's tundra fz",
#  'pink americana tshirt',
#  'nike set nwt .',
#  '4 paperm pencil 0.7mm',
#  'suprem script beani fw 2016',
#  'winter bundl',
#  'samsung on5 dual tech hybrid case',
#  'lularo leg',
#  'new nike benassi jdi',
#  'tommi girl',
#  'sperri top-sid boat shoe size 7.5m',
#  'nike shox size 2c',
#  'two toddler two piec set',
#  'v-neck tshirt bundl',
#  'ban 1',
#  'polo ralph lauren',
#  'color notebook 6 pack bundl',
#  'wolf man # 114 funko hold',
#  'black forever21 heel',
#  "vintag namb 562 1960 's",
#  'chanel well love brush bundl ! authenti',
#  'airoptix blue pair contact',
#  'american girl book',
#  'high waist denim distress short',
#  'origin brand new adida nmdr',
#  'soda stream',
#  'adult mouth guard1 black 1 clear',
#  "woman 's green tshirt",
#  'ofra beverli hill highlight',
#  'jagger',
#  'summer dress',
#  'outr neesha lace front wig color dr30',
#  'loeffler randal envelop clutch',
#  'spanish everyon nd',
#  'iphon 6/6 plu case',
#  'tommi hilfig',
#  'j . crew militari green roll sleev tee',
#  'men plaid button shirt',
#  "blue adida size 11 men 's",
#  'final price ! nikon coolpix l830',
#  'dose color eye cream palett',
#  'honey & spice ▪️new fall scent !',
#  'lularo butterfli',
#  'armour black compress shirt',
#  'master visor hat',
#  'say/ say english book',
#  'discontinu mango tango twist fragranc',
#  'nwt med v pad bandeau',
#  'wildfox coutur sweetheart cuti short',
#  'white fuzzi slipper ( return soon )',
#  'kate spade wallet',
#  'stripe sexi dress',
#  'new 18k gold cross necklac',
#  'chocol soleil bronzer',
#  'barbi articul ken male doll',
#  '3-6 month swim set',
#  "nike men 's size 9 hyperdunk red",
#  'wet n wild makeup lot',
#  '12 outfit',
#  'f ! sleep right dental guard boil new',
#  'new 2 pair nike long sock girl 9c-13c',
#  'shoulder top small',
#  'purpl gymshark tank top',
#  "victoria 's secret leg",
#  'woman booti boot . never worn',
#  'loos glitter',
#  'sport bra bundl',
#  'pandora adjust silver necklac',
#  'north face woman medium',
#  'sale ! three pink bodi mist !',
#  'michael kor purpl leather tote',
#  'plastic sunglass reserv mylah .',
#  'drug rug sweater',
#  'kid wall abc canva',
#  'victoria secret bodi spray',
#  'dooney bourk wallet',
#  'small pocket bling mirror',
#  'plexu slim & ( 2 ) pro bio',
#  'floral torrid shirt size 2',
#  'ugg size 12 13',
#  'kawaii bow choker',
#  'rhineston hoop ear',
#  'dooney bourk',
#  'kzw matilda jane sham',
#  '✨soft sateen jeg',
#  'euc lularo leg',
#  'cage push bralett',
#  'avon penguin 1990 tumbler glass',
#  'physician formula bronzer',
#  'red shift dress',
#  'final fantasi 13 free ship ps3',
#  'v pink hoodi',
#  'mohawk rabbit fur & fox fur vest',
#  'reserv travi mendez',
#  'ladi size 2x chevron dress',
#  'labret self bodi pierc jewelri kit',
#  'babi boy onesi bundl',
#  'v sport short sleev hoodi',
#  'pink water bottl',
#  'eyelash brow growth serum :',
#  'white popclip stand popsocket mount new',
#  'babygap 1969',
#  'bb curl style bundl',
#  'harem jogger',
#  '6-9 month bundl',
#  'fossil vintag renew purs',
#  'rose pink lace dress',
#  'juici coutur bag good condit',
#  'new philosophi loveswept perfum',
#  'size 7 black forev 21 sandal',
#  'cricut bundl jackson',
#  'nike dri-fit shirt',
#  'undef t-shirt',
#  'elimin coffe breath & remov stain !',
#  'black volcom tier tank',
#  'alpinestar jacket',
#  'larg fitbit charg 2',
#  'ugg bailey bow boot size 7',
#  'light amber 925 plate ring 10',
#  'face better sex mascara',
#  'plane fire rescu blu ray + dvd',
#  'zip jacket',
#  'laura mercia powder',
#  'thirti one bag/purs',
#  'bundl happi',
#  '5 mac primer',
#  'kendra scott alex ear',
#  'black booti',
#  'face skinni dip london makeup bag',
#  'vera bradley shower vine day tote',
#  'nwt small lularo sarah',
#  'anarkali dress',
#  'youniqu splash lipstick sentiment',
#  'find dori blanket & pillow',
#  "free ship -- men 's new flojo size 10",
#  'ny & co. blous',
#  'splat pink fetish rose hair dye',
#  'lularo kid s/m leg 2/pk',
#  'tippmann cyclon hopper free ship',
#  'babi dress cardigan set',
#  'v pink sandl bundl',
#  'black booti carlo santana',
#  'mari kay clear lip liner',
#  '[ rm ] lululemon gift card',
#  'fabrik tie dye maxi dress nwt',
#  'cute booti',
#  'afflict shirt',
#  'custom order',
#  'nike hurachi men size 8.5',
#  'turtl night lamp',
#  'mk black iphon 6 / 6 wallet case',
#  'bad feminist roxan gay',
#  'convers',
#  'cotton embroid dress never worn',
#  'cheer bow bundl cheetah white',
#  'vera bradley backpack',
#  'shoulder top xl',
#  'deep sea cosmet bodi butter & scrub',
#  "nwt l.a idol jean 's size 9",
#  '( 200 ) self adhes thank sticker',
#  'nib aveda tripl accent olive/quinc',
#  'free ship bbw lotion tahiti island dream',
#  'vintag ge transistor radio',
#  'fairi tale lous prevent condit spray',
#  'bare miner readi face color palett',
#  'ralph lauren pj sleeper boy 3m',
#  'mari kay lipstick- red salsa',
#  'usc cheerlead outfit 12 month',
#  '( 36d ) f ! victoria secret bra',
#  'merc scentsi koala',
#  '2 cute ring size 8',
#  'set 4 skull underwear',
#  'lularo eleg irma',
#  'countri decor',
#  'flat shoe',
#  'brow wiz',
#  'lularo halloween bn china',
#  'new england patriot shirt',
#  'babi polo button-up',
#  '3 - pamper size 3',
#  'grate dead bear beach towel',
#  'free ship unicorn lularo cassi skirt',
#  'new••authent yeti bundl',
#  'gray sweater size',
#  'men underwear',
#  'bundl bluebird310',
#  'ugg toddler chestnut',
#  'hollist top',
#  'asic volleybal shoe',
#  'rae dunn oval plate ( hold melissa )',
#  "boy 's h & hood puffer jacket coat navi",
#  'sperri loafer',
#  "woman 's bomber jacket size small",
#  'simpli southern long sleev t-shirt',
#  'ipad pro smart cover',
#  'sale ! ❤ ship today ! logo boyshort',
#  'adida shoes- elizabeth',
#  "victoria 's secret panti bundl",
#  'john deer toy',
#  'sakura pen',
#  'littl peopl farm',
#  'cosmet light celebr foundatio',
#  'garanim 2t fleec zip 2 piec',
#  '1st birthday boy parti bundl',
#  'tween lularo flower',
#  'skirt',
#  'h & bikini',
#  'gopro hero + bundl extra !',
#  'kyli holiday palett | kyshadow',
#  'ipod nano 7th gener',
#  'strapless maxi dress nwt',
#  'harri potter pc game free ship',
#  'pure romanc ben wa ball',
#  'mauv ice lipsens free ship',
#  'pandora bracelet',
#  'fine mink eyelash 3 pair',
#  'jeffre star cosmet liquid lipstick',
#  'iphon 6/6 otter box',
#  'loui vuitton wallet',
#  "woman 's columbia jacket",
#  'sale ! [ rm ] 2 morph brush',
#  'free ship coach red purs',
#  'new vera bradley parisian paisley bundl',
#  'koala babi 0-3 month babi boy outfit',
#  'nike meadow `` 16 txt new . ( 8.5 )',
#  'new aviat tula blanket',
#  'lularo kid sm/med octopu',
#  'marisol lot hold appl',
#  'wildfox love backstag pa hoodi',
#  'ultim l.b.d .',
#  'creme powder foundat',
#  'nwt bath towel',
#  'kate spade purs like new',
#  'black nike size 5 c',
#  'better fals lash face',
#  'clark bendabl mari jane wedg',
#  'abh modern renaiss palett',
#  'hold - hakunamatata - aero ombré leg',
#  '1 contour palett spong',
#  '2 brand new dolman style top xl/2xl',
#  'harri style magazin',
#  'convers chuck taylor navi blue',
#  'fashion jewerli',
#  'lilli & kate mug , purs & stopper',
#  'freeship rae dunn latt mug',
#  'namast bed tee shirt',
#  'zip/button jacket',
#  "free ship ! ( 6/7 ) victoria 's secret pink",
#  'iphon 4',
#  'babi boy woodi outfit n notepad',
#  'black sparkli stretchi turtleneck',
#  'freeship lg tone pro pink',
#  'chicken paint frame',
#  'oshkosh 3t laci ivori top',
#  'thrasher shirt ( authent )',
#  'funko pop albu dumbledor & hermion',
#  'stripper shoe',
#  'reserv angi cupp',
#  '4 stranger thing funko pop',
#  'pantilin bundl',
#  '18month bundl babi cloth 200 $ worth',
#  "levi 's",
#  'shopkin stamp set',
#  'men timberland boot',
#  'hayley william b & w tripp leather jacket',
#  'home decor',
#  'face lip inject extrem',
#  'kyli birthday mini matt',
#  'nwt shoulder blous',
#  'cute cat sticker',
#  'boy jordan shirt & short',
#  'fabl 2 & 3',
#  'victoria secret bottl open glass',
#  'h & one piec',
#  'loui vuitton box includ dust bag',
#  'brand new',
#  'pink north face vest',
#  'adida sweatpant',
#  'nightmar christma salli tea pot',
#  'born way natur beig',
#  'shiseido white / blue stripe larg tote',
#  'resid evil 4 nintendo gamecub',
#  'nwt minecraft lego',
#  'hatchim wal-mart exclus burtl',
#  'small nwt detroit tiger fit tee',
#  'wet n wild highlight palett',
#  '3-6 month babi cloth',
#  'aeropastal l white button',
#  'v pink bling campu crew x',
#  'vineyard vine long sleev',
#  "girl 's appl bottom 3pc 18mth",
#  'navi tan gucci satchel',
#  'new maybellin master contour stick',
#  'free ship button top',
#  'pulitz dress',
#  "men 's essenti",
#  'froslass holo',
#  'michael kor infin scarf',
#  'kind day sale abh brush # 12',
#  'digit hairstraighten brush+freeglov',
#  'xl ralph lauren sweater',
#  'michael jordan sneaker 6y',
#  'pink pink t-shirt',
#  'burberri belt wallet pouch',
#  'woman shoe color 12wide',
#  'price reduc ! ! ! lularo nicol size l',
#  'brevil juic power elit',
#  'foot detox pad',
#  'face better sex mascara',
#  'michael kor crossbodi purs',
#  'bundl lexi jo',
#  'lululemon leg',
#  'fitbit charg hr',
#  'bbw 2 new 10 oz shower gel',
#  'victoria secret bra',
#  'men lucki jean size 38 x 32',
#  '4 juici coutur onesi girl',
#  'free ship 24pc pro makeup brush',
#  'mug : dream reserv',
#  'ivori ella ombr tshirt',
#  'lee sin soft size 8 slack',
#  'babi girl sandal size 6 free ship',
#  'luxuri bath bomb bundl',
#  'ombré crewneck sweatshirt',
#  'blush forev 21 dress',
#  'black levi 529',
#  'metal gear solid v : phantom pain new',
#  'tc black vintag camera leg lularo',
#  'winnie-the-poah , origin version',
#  'christian louboutin tudor bal 100',
#  'larg coach shoulder bag',
#  'newborn crotchet christma photo prop',
#  'brand new harley davidson slipper !',
#  '925 silver wed band promis ring',
#  'snake/gold tori burch miller sandal 7.5',
#  'laura mercier loos transluc powder',
#  'coach black chelsea handbag',
#  'nike shox junior new sz . 9',
#  'brabd new pink north face girl hoodi',
#  'solar system magnet set',
#  'chargeabl phone case iphon 6/6',
#  'new ! tight black skirt w/ gold button',
#  'almost famou skinni jean',
#  'onesi & disney outfit',
#  'lilli pulitz pink crochet dress',
#  'kay von contour',
#  'boutiqu ear',
#  'cleveland indian clutch',
#  'iphon 6 wine case',
#  '3 carter pj boy 4t kati harri',
#  'iphon 6/6 case',
#  'glass & crank ellen hopkin',
#  'adida',
#  'complet harri potter seri paperback',
#  'chase funko dorbz',
#  'candi / snack bundl',
#  '40 thank sticker',
#  'sondra robert larg beig woven handbag',
#  'pink crop sweat pant',
#  '* bundl ( ) v pink quarter zip jacket !',
#  'urban outfitt shirt !',
#  'thuy make bundl [ rm ]',
#  'bnwt lularo julia size small',
#  'place like home wizard oz cabuchon',
#  'revers handmad jumper/dress sz 2/3',
#  'manni ramirez jersey',
#  'marvel legend iron patriot',
#  'oliv colorblock cowl neck x',
#  'new authent burberri shirt men xl',
#  "valentin 's day toilet paper",
#  'lularo peek santa leg .',
#  'kyli cosmet holiday naughti gloss',
#  'lularo hula dancer , .',
#  'new 18k gold cartier love bracelet',
#  'esté lauder 2n1 desert beig',
#  'pretti littl thing bodycon bardot dress',
#  '2 iphon 6/6 wallet case',
#  'bnwt lularo gigi - steel blue size',
#  'lululemon crop',
#  'lot lularo leg',
#  'nwot st.loui cardin zip-up xl hoodi',
#  'pali hawaiian jesu sandal',
#  'black high heel',
#  'instyl',
#  'bundl',
#  'victoria secret eye mask',
#  'victoria secret pink shirt bling size',
#  'armor fleec hoodi',
#  'lululemon leg size 6 blue',
#  'game boy advanc tekken',
#  'michael kor bag .',
#  'v pink strapless bra',
#  'floral leg',
#  'new design woman urin soft silicon',
#  "woman 's .925 silver bead bracelet",
#  'lularo russian doll . nwt .',
#  'bath bodi work scent',
#  'nike shoe',
#  'babi girl shoe',
#  "victoria 's secret sexi touch",
#  'jamberry- mind game matt 1/2 sheet',
#  'blue strappi bikini -',
#  'elf bundl',
#  'urban decay',
#  'brandi melvil short',
#  'lcd monitor asu 1080 full hd',
#  'atlanta brave chipper jone jersey',
#  'lularo grey sweater joy nwt free ship',
#  "'spot ! ' parti game - mlb edit * new",
#  'rae dunn thanksgiv mug',
#  'lot 2 puma nike 2t athlet short',
#  "new rae dunn 4 happi easter 6 '' plate",
#  'geneva gold watch',
#  'tattoo choker',
#  'dork diari lot 3',
#  'grey convers',
#  'doc mcstuffin activ set kit toy',
#  'stila liquid lipstick',
#  'nwt- white mesh nike tank',
#  'bior nose face strip blackhead remov',
#  'toddler 9 convers .',
#  'lularo julia size l feather',
#  'handmad chakra spray',
#  'black leather gap cross sandal',
#  'essenti oil mini set',
#  'keen size 10 ( woman ) vguc reserv',
#  'lume iphon 6 plu',
#  'packer sweatpant',
#  'cloth pad',
#  'nurs mate shoes/clog ! ador ! 6m',
#  'lululemon sculpt short 2',
#  '( 4 ) lululemon wunder crop !',
#  'vineyard vine skirt',
#  'lularo bambi',
#  "`` key heart '' silver alex ani",
#  'nwot purpl grey northfac hood jacket',
#  'lularo leg',
#  'chanel white purs',
#  'h & high waist pant',
#  'hollist sweatpant size',
#  'blue kate spade crossbodi',
#  'top',
#  'babi bottl squishi',
#  'girl jelli sandal 9',
#  'scrub pant',
#  'new iphon 6/6 purpl ombr soft case',
#  'american eagl distress skinni jean',
#  'lume rose gold iphon 6 case',
#  'hair curler',
#  'love flip flop car decal sticker',
#  'lp lot 4 cute pet',
#  'hold melissasephora gift card',
#  's/m volcom flexfit hat !',
#  'minoloon size 3-12 month cloth pant',
#  'like new lululemon herringbon pullov',
#  ...]

# %%
Count_titulos = vectorizer.fit_transform((train1['name']))
Count_titulos
# Out:
# <1476204x105308 sparse matrix of type '<class 'numpy.int64'>'
# 	with 6210528 stored elements in Compressed Sparse Row format>
